# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_extraction.text import CountVectorizer
import arff
import pandas as pd
import re

def weka_tokenizer(doc):
    delimiters_regexp = re.compile("[ |\n|\f|\r|\t|.|,|;|:|'|\"|(|)|?|!]")
    # delimiters_regexp = re.compile("[ -\/:-@\[-\`{-~|0-9|\n|\f|\r|\t|\s]")
    return list(filter(None, delimiters_regexp.split(doc)))

# %%
data = pd.read_csv('../../datasets/flakies_rq_21.csv')

df = pd.DataFrame(data, columns=['tokens', 'loc', 'abstract_keyword', 'assert_keyword', 'boolean_keyword', 'break_keyword', 'byte_keyword', 'case_keyword', 'catch_keyword', 'char_keyword', 'class_keyword', 'continue_keyword', 'default_keyword', 'do_keyword', 'double_keyword', 'else_keyword', 'enum_keyword', 'exports_keyword', 'extends_keyword', 'final_keyword', 'finally_keyword', 'float_keyword', 'for_keyword', 'if_keyword', 'implements_keyword', 'import_keyword', 'instanceof_keyword', 'int_keyword', 'interface_keyword', 'long_keyword', 'modules_keyword', 'native_keyword', 'new_keyword', 'package_keyword', 'private_keyword', 'protected_keyword', 'public_keyword', 'requires_keyword', 'return_keyword', 'short_keyword', 'static_keyword', 'strictfp_keyword', 'super_keyword', 'switch_keyword', 'synchronized_keyword', 'this_keyword', 'throw_keyword', 'throws_keyword', 'transient_keyword', 'try_keyword', 'void_keyword', 'volatile_keyword', 'while_keyword', 'true_keyword', 'null_keyword', 'false_keyword', 'const_keyword', 'goto_keyword', 'keywordcount', 'klass'])

y = df['klass']

vectorizer = CountVectorizer(analyzer='word', max_features=1551, tokenizer=weka_tokenizer) 
bowToken = vectorizer.fit_transform(df['tokens'])

bowData = pd.DataFrame(bowToken.toarray(), columns=vectorizer.get_feature_names())
df.drop('tokens', axis=1, inplace=True)
df.drop('klass', axis=1, inplace=True)
df = df.join(bowData)

informationGain = dict(zip(df.columns, mutual_info_classif(df, y, discrete_features=True)))

df = df.join(y)

sortedInformationGain = sorted(informationGain, key=informationGain.get, reverse=True)

# %%
i = 0
sortedInformationGainPosition = []

for r in sortedInformationGain:    

    infGain = {
        'position': i, 
        'token': r, 
        'information_gain': informationGain[r], 
        'total_ocurences': len(df[ df[r] > 0 ] ), 
        'total_flaky_occurences': len(df[ (df[r] > 0)  & (df['klass'] == "Flakey") ]), 
        'total_nonflaky_occurences': len(df[ (df[r] > 0)  & (df['klass'] == "Non_Flakey") ])
    }

    sortedInformationGainPosition.append(infGain)
    i += 1

    print(i, r, informationGain[r])
    

infGainCSV = pd.DataFrame(sortedInformationGainPosition, columns=['position', 'token', 'information_gain', 'total_ocurences', 'total_flaky_occurences', 'total_nonflaky_occurences'])
infGainCSV.to_csv('information_gain_rq_21.csv')
# Out:
# 1 public_keyword 8.187894806610529e-16
# 2 acl 8.187894806610529e-16
# 3 created 8.187894806610529e-16
# 4 reader 8.187894806610529e-16
# 5 createdirwithhttp 7.91033905045424e-16
# 6 createsnapshot 7.91033905045424e-16
# 7 directory 7.91033905045424e-16
# 8 folder 7.91033905045424e-16
# 9 gethadoopusers 7.91033905045424e-16
# 10 hadoopusersconftesthelper 7.91033905045424e-16
# 11 init 7.91033905045424e-16
# 12 no 7.91033905045424e-16
# 13 touri 7.91033905045424e-16
# 14 write 7.91033905045424e-16
# 15 assertnotnull 1.1102230246251565e-16
# 16 loc 0.0
# 17 abstract_keyword 0.0
# 18 assert_keyword 0.0
# 19 boolean_keyword 0.0
# 20 break_keyword 0.0
# 21 byte_keyword 0.0
# 22 case_keyword 0.0
# 23 catch_keyword 0.0
# 24 char_keyword 0.0
# 25 class_keyword 0.0
# 26 continue_keyword 0.0
# 27 default_keyword 0.0
# 28 do_keyword 0.0
# 29 double_keyword 0.0
# 30 else_keyword 0.0
# 31 enum_keyword 0.0
# 32 exports_keyword 0.0
# 33 extends_keyword 0.0
# 34 final_keyword 0.0
# 35 finally_keyword 0.0
# 36 float_keyword 0.0
# 37 for_keyword 0.0
# 38 if_keyword 0.0
# 39 implements_keyword 0.0
# 40 import_keyword 0.0
# 41 instanceof_keyword 0.0
# 42 int_keyword 0.0
# 43 interface_keyword 0.0
# 44 long_keyword 0.0
# 45 modules_keyword 0.0
# 46 native_keyword 0.0
# 47 new_keyword 0.0
# 48 package_keyword 0.0
# 49 private_keyword 0.0
# 50 protected_keyword 0.0
# 51 requires_keyword 0.0
# 52 return_keyword 0.0
# 53 short_keyword 0.0
# 54 static_keyword 0.0
# 55 strictfp_keyword 0.0
# 56 super_keyword 0.0
# 57 switch_keyword 0.0
# 58 synchronized_keyword 0.0
# 59 this_keyword 0.0
# 60 throw_keyword 0.0
# 61 throws_keyword 0.0
# 62 transient_keyword 0.0
# 63 try_keyword 0.0
# 64 void_keyword 0.0
# 65 volatile_keyword 0.0
# 66 while_keyword 0.0
# 67 true_keyword 0.0
# 68 null_keyword 0.0
# 69 false_keyword 0.0
# 70 const_keyword 0.0
# 71 goto_keyword 0.0
# 72 keywordcount 0.0
# 73 $radius 0.0
# 74 $side 0.0
# 75 &infofilters=info2%20eq%203 0.0
# 76 &snapshotname=snap-renamed 0.0
# 77 * 0.0
# 78 + 0.0
# 79 - 0.0
# 80 --- 0.0
# 81 / 0.0
# 82 // 0.0
# 83 //localhost 0.0
# 84 /acldirtest 0.0
# 85 /aclfiletest 0.0
# 86 /file 0.0
# 87 /file1 0.0
# 88 /file2 0.0
# 89 /foo 0.0
# 90 /html 0.0
# 91 /noacls 0.0
# 92 /noxattr 0.0
# 93 /perm 0.0
# 94 /perm/none 0.0
# 95 /perm/p-321 0.0
# 96 /perm/p-654 0.0
# 97 /perm/p-777 0.0
# 98 /rm 0.0
# 99 /test 0.0
# 100 /tmp 0.0
# 101 /tmp/foo 0.0
# 102 /tmp/foo1 0.0
# 103 /tmp/foo2 0.0
# 104 /tmp/log 0.0
# 105 /tmp/notunmasked 0.0
# 106 /tmp/notunmaskeddir 0.0
# 107 /tmp/tmp-snap-allow-test 0.0
# 108 /tmp/tmp-snap-diff-exc-test 0.0
# 109 /tmp/tmp-snap-diff-test 0.0
# 110 /tmp/tmp-snap-disallow-exception-test 0.0
# 111 /tmp/tmp-snap-disallow-test 0.0
# 112 /tmp/tmp-snap-test/ 0.0
# 113 /tmp/unmasked 0.0
# 114 /tmp/unmaskeddir 0.0
# 115 /tmplog 0.0
# 116 /webhdfs/v1 0.0
# 117 /webhdfs/v1/foo 0.0
# 118 /webhdfs/v1/tmp/foo 0.0
# 119 /webhdfs/v1{0} 0.0
# 120 /ws/ 0.0
# 121 /ws/chat/bob 0.0
# 122 /ws/v2/ 0.0
# 123 /ws/v2/timeline/ 0.0
# 124 /xattrtest 0.0
# 125 0 0.0
# 126 0000 0.0
# 127 001 0.0
# 128 1 0.0
# 129 10px 0.0
# 130 1425016502010 0.0
# 131 14px 0.0
# 132 1@ 0.0
# 133 2 0.0
# 134 3 0.0
# 135 321 0.0
# 136 4 0.0
# 137 5 0.0
# 138 5&createdtimestart=1425016502030& 0.0
# 139 618 0.0
# 140 654 0.0
# 141 700 0.0
# 142 755 0.0
# 143 777 0.0
# 144 =1425016502010 0.0
# 145 [oak 0.0
# 146 \ 0.0
# 147 \d{3} 0.0
# 148 \d{6} 0.0
# 149 \d{8} 0.0
# 150 \{\ 0.0
# 151 \} 0.0
# 152 _1 0.0
# 153 a 0.0
# 154 a1 0.0
# 155 a2 0.0
# 156 ab7822c10f1111 0.0
# 157 about 0.0
# 158 accurately 0.0
# 159 acl-based 0.0
# 160 aclbit 0.0
# 161 aclentries 0.0
# 162 aclentryscope 0.0
# 163 aclentrytype 0.0
# 164 aclgroup1 0.0
# 165 acls 0.0
# 166 aclspec 0.0
# 167 aclspec= 0.0
# 168 aclspec=user 0.0
# 169 aclstatus 0.0
# 170 acluser1 0.0
# 171 acluser2 0.0
# 172 add 0.0
# 173 addcolumn 0.0
# 174 addconfigs 0.0
# 175 addconverterfactory 0.0
# 176 added 0.0
# 177 addendpoint 0.0
# 178 addentity 0.0
# 179 addfamily 0.0
# 180 addinfo 0.0
# 181 addmetrics 0.0
# 182 addsystemacl 0.0
# 183 admin 0.0
# 184 adminugi 0.0
# 185 adminuser 0.0
# 186 after 0.0
# 187 all 0.0
# 188 allof 0.0
# 189 allow 0.0
# 190 allowed 0.0
# 191 allowsnapshot 0.0
# 192 already 0.0
# 193 always 0.0
# 194 an 0.0
# 195 and 0.0
# 196 annotatedclientendpoint 0.0
# 197 another 0.0
# 198 anymore 0.0
# 199 api 0.0
# 200 app 0.0
# 201 app-attempt-1 0.0
# 202 app-attempt-2 0.0
# 203 app-attempt1 0.0
# 204 app-attempt2 0.0
# 205 app-error 0.0
# 206 app1_group1 0.0
# 207 app1_group12 0.0
# 208 app1_group1_2 0.0
# 209 app1_group2 0.0
# 210 app2 0.0
# 211 app2_group1 0.0
# 212 appattempts/app-attempt-1/containers 0.0
# 213 appattempts/app-attempt-2/containers 0.0
# 214 appdirclean 0.0
# 215 appdirempty 0.0
# 216 appdirholdbydir 0.0
# 217 appdirholdbyfile 0.0
# 218 appdirname 0.0
# 219 append 0.0
# 220 appid 0.0
# 221 application 0.0
# 222 application_1501509265053_0001 0.0
# 223 applicationattemptid 0.0
# 224 applicationid 0.0
# 225 applogs 0.0
# 226 appname 0.0
# 227 appstate 0.0
# 228 are 0.0
# 229 around 0.0
# 230 array 0.0
# 231 arrays 0.0
# 232 as 0.0
# 233 asking 0.0
# 234 aslist 0.0
# 235 assert 0.0
# 236 assertarrayequals 0.0
# 237 assertequals 0.0
# 238 assertfalse 0.0
# 239 assertnotempty 0.0
# 240 assertnotequals 0.0
# 241 assertnull 0.0
# 242 assertthat 0.0
# 243 asserttrue 0.0
# 244 attemotdirpath 0.0
# 245 attemptdirclean 0.0
# 246 attemptdirempty 0.0
# 247 attemptdirholdbydir 0.0
# 248 attemptdirholdbyfile 0.0
# 249 attemptdirname 0.0
# 250 attributes 0.0
# 251 await 0.0
# 252 back 0.0
# 253 bar 0.0
# 254 based 0.0
# 255 basetablerw 0.0
# 256 baseurl 0.0
# 257 batch 0.0
# 258 batchlimit 0.0
# 259 be 0.0
# 260 because 0.0
# 261 been 0.0
# 262 before 0.0
# 263 beforescan 0.0
# 264 bit 0.0
# 265 bob 0.0
# 266 body 0.0
# 267 build 0.0
# 268 builder 0.0
# 269 but 0.0
# 270 by 0.0
# 271 bytes 0.0
# 272 c 0.0
# 273 c1 0.0
# 274 cache 0.0
# 275 caching 0.0
# 276 call 0.0
# 277 called 0.0
# 278 calls 0.0
# 279 cancel 0.0
# 280 cancelall 0.0
# 281 canceled 0.0
# 282 cancelokhttprequest 0.0
# 283 cancelrequest 0.0
# 284 case 0.0
# 285 cells 0.0
# 286 check 0.0
# 287 checkaccess 0.0
# 288 checktranslation 0.0
# 289 clean 0.0
# 290 cleaned 0.0
# 291 cleaner 0.0
# 292 cleanlogs 0.0
# 293 client 0.0
# 294 clock 0.0
# 295 close 0.0
# 296 closed 0.0
# 297 closereason 0.0
# 298 cluster 0.0
# 299 cluster_test_write_entity 0.0
# 300 clusters/cluster1/apps/app1/entities/app 0.0
# 301 clusters/cluster1/apps/app1/entities/app/id_1 0.0
# 302 colcount 0.0
# 303 collections 0.0
# 304 column 0.0
# 305 column2 0.0
# 306 column3 0.0
# 307 column4 0.0
# 308 columnname2bytes 0.0
# 309 columnname3bytes 0.0
# 310 columnname4bytes 0.0
# 311 columnnamebytes 0.0
# 312 columnrwhelper 0.0
# 313 com 0.0
# 314 commands 0.0
# 315 commonconfigurationkeyspublic 0.0
# 316 comparision 0.0
# 317 comparison 0.0
# 318 compoundvalue 0.0
# 319 conf 0.0
# 320 conf2 0.0
# 321 conffilters=config_1%20eq%20123%20and%20config_3%20eq%20abc 0.0
# 322 config 0.0
# 323 config_param1 0.0
# 324 config_param2 0.0
# 325 configcolumns 0.0
# 326 configuration 0.0
# 327 configurator 0.0
# 328 conn 0.0
# 329 connect 0.0
# 330 connectionfactory 0.0
# 331 connecttoserver 0.0
# 332 container 0.0
# 333 container_1_1 0.0
# 334 container_2_1 0.0
# 335 container_2_2 0.0
# 336 containerprovider 0.0
# 337 containers 0.0
# 338 contains 0.0
# 339 containskey 0.0
# 340 content 0.0
# 341 convertapplicationidtostring 0.0
# 342 correct 0.0
# 343 count 0.0
# 344 countdown 0.0
# 345 counters 0.0
# 346 cr 0.0
# 347 create 0.0
# 348 createandstarttimelinestore 0.0
# 349 createclient 0.0
# 350 createconnection 0.0
# 351 createdtimeend 0.0
# 352 createdtimeend=1425016502060 0.0
# 353 createdtimestart= 0.0
# 354 createdtimestart=1425016502030&createdtimeend=1425016502060 0.0
# 355 createentities 0.0
# 356 createentity 0.0
# 357 createfilesystem 0.0
# 358 createhadoopconf 0.0
# 359 createhttpfsserver 0.0
# 360 createmode 0.0
# 361 createremoteuser 0.0
# 362 createsaslaclfromcurrentuser 0.0
# 363 createtestfiles 0.0
# 364 createwithhttp 0.0
# 365 creating 0.0
# 366 creation 0.0
# 367 ctime 0.0
# 368 ctime1 0.0
# 369 curatorservice 0.0
# 370 currenttimemillis 0.0
# 371 custom 0.0
# 372 dat 0.0
# 373 data 0.0
# 374 default 0.0
# 375 defaultrealm 0.0
# 376 defaultserver 0.0
# 377 defspec1 0.0
# 378 defuser1 0.0
# 379 delegationtokencommontests 0.0
# 380 delete 0.0
# 381 deletesnapshot 0.0
# 382 delimiters 0.0
# 383 deployment 0.0
# 384 deployservlet 0.0
# 385 destroy 0.0
# 386 dfs 0.0
# 387 dfsdiffreport 0.0
# 388 did 0.0
# 389 diff 0.0
# 390 dir 0.0
# 391 dirpathempty 0.0
# 392 dirpathhold 0.0
# 393 dirs 0.0
# 394 dirscleaned 0.0
# 395 disabled 0.0
# 396 disallowsnapshot 0.0
# 397 dispatcher 0.0
# 398 doas 0.0
# 399 domain 0.0
# 400 domain_1 0.0
# 401 domain_id_1 0.0
# 402 domainloginfo 0.0
# 403 don 0.0
# 404 doneapphomedir 0.0
# 405 drwho 0.0
# 406 due 0.0
# 407 duration 0.0
# 408 e 0.0
# 409 e1 0.0
# 410 effect 0.0
# 411 effective 0.0
# 412 either 0.0
# 413 element 0.0
# 414 empty 0.0
# 415 enable 0.0
# 416 enabled 0.0
# 417 end 0.0
# 418 endpoint 0.0
# 419 enough 0.0
# 420 enqueue 0.0
# 421 entities 0.0
# 422 entities/yarn_application_attempt 0.0
# 423 entities/yarn_container/container_2_2 0.0
# 424 entities1 0.0
# 425 entities2 0.0
# 426 entity 0.0
# 427 entity3 0.0
# 428 entitycolumn 0.0
# 429 entitycolumnprefix 0.0
# 430 entitygroupfstimelinestore 0.0
# 431 entitygrouppluginfortest 0.0
# 432 entitylist 0.0
# 433 entitynew 0.0
# 434 entries 0.0
# 435 entry 0.0
# 436 entryset 0.0
# 437 enumset 0.0
# 438 environment 0.0
# 439 equals 0.0
# 440 error 0.0
# 441 es1 0.0
# 442 event_4 0.0
# 443 eventfilters=event_2 0.0
# 444 events 0.0
# 445 exceptions 0.0
# 446 execute 0.0
# 447 executedue 0.0
# 448 executequery 0.0
# 449 executions 0.0
# 450 executiontime 0.0
# 451 exists 0.0
# 452 expect 0.0
# 453 expected 0.0
# 454 expectedlogs 0.0
# 455 expectedpath 0.0
# 456 ez 0.0
# 457 ezfile 0.0
# 458 ezpath 0.0
# 459 fail 0.0
# 460 failed 0.0
# 461 fails 0.0
# 462 failureref 0.0
# 463 failures 0.0
# 464 false 0.0
# 465 familiar 0.0
# 466 family 0.0
# 467 far 0.0
# 468 fetch 0.0
# 469 field 0.0
# 470 fields 0.0
# 471 fields=all 0.0
# 472 fields=configs 0.0
# 473 file 0.0
# 474 file1 0.0
# 475 file2 0.0
# 476 filepath 0.0
# 477 filepathhold 0.0
# 478 filestatus 0.0
# 479 filesystem 0.0
# 480 filesystemcache 0.0
# 481 filesystemexecutor 0.0
# 482 filter 0.0
# 483 findaclwithname 0.0
# 484 findelement 0.0
# 485 finished 0.0
# 486 first 0.0
# 487 flow 0.0
# 488 flow1 0.0
# 489 flow1&eventfilters=event_2 0.0
# 490 flowruncolumnfamily 0.0
# 491 flowrunid=2ab15 0.0
# 492 flowrunid=a23b 0.0
# 493 flowruntable 0.0
# 494 flowruntablerw 0.0
# 495 flowversion 0.0
# 496 font-size 0.0
# 497 foo 0.0
# 498 for 0.0
# 499 forceclose 0.0
# 500 format 0.0
# 501 fourth 0.0
# 502 frequency 0.0
# 503 from 0.0
# 504 from_id 0.0
# 505 fromid 0.0
# 506 fromstring 0.0
# 507 fs 0.0
# 508 fs1 0.0
# 509 fs2 0.0
# 510 fsa 0.0
# 511 fsaction 0.0
# 512 get 0.0
# 513 getabout 0.0
# 514 getabsolutepath 0.0
# 515 getaclentries 0.0
# 516 getaclstatus 0.0
# 517 getappdirpath 0.0
# 518 getasyncremote 0.0
# 519 getattemptdirname 0.0
# 520 getbasicremote 0.0
# 521 getbufferpool 0.0
# 522 getbytes 0.0
# 523 getclosecode 0.0
# 524 getcode 0.0
# 525 getconfigs 0.0
# 526 getconfiguration 0.0
# 527 getcreatedtime 0.0
# 528 getcurrentuser 0.0
# 529 getcurrentusernameunencoded 0.0
# 530 getcurrentwindow 0.0
# 531 getdeclaredfield 0.0
# 532 getdefaultrealm 0.0
# 533 getdescription 0.0
# 534 getdir 0.0
# 535 getdomain 0.0
# 536 geteffectivepermission 0.0
# 537 getentities 0.0
# 538 getentitiesreadtosummary 0.0
# 539 getentity 0.0
# 540 getentityid 0.0
# 541 getentitytype 0.0
# 542 getevents 0.0
# 543 getfamilymap 0.0
# 544 getfile 0.0
# 545 getfilestatus 0.0
# 546 getfilesystemconfiguration 0.0
# 547 getgetentitytosummaryops 0.0
# 548 gethdfsconf 0.0
# 549 gethdfstestdir 0.0
# 550 gethomedir 0.0
# 551 gethostaddress 0.0
# 552 gethostport 0.0
# 553 getid 0.0
# 554 getinfo 0.0
# 555 getinputstream 0.0
# 556 getisrelatedtoentities 0.0
# 557 getjettyurl 0.0
# 558 getkey 0.0
# 559 getloginuser 0.0
# 560 getlogs 0.0
# 561 getlogsdirscleaned 0.0
# 562 getmessage 0.0
# 563 getmetrics 0.0
# 564 getname 0.0
# 565 getowner 0.0
# 566 getpath 0.0
# 567 getperms 0.0
# 568 getprocedure 0.0
# 569 getreaders 0.0
# 570 getrealm 0.0
# 571 getreason 0.0
# 572 getreasonphrase 0.0
# 573 getrelatestoentities 0.0
# 574 getresponse 0.0
# 575 getresponsecode 0.0
# 576 getresult 0.0
# 577 getresultscanner 0.0
# 578 getrow 0.0
# 579 getrowkeyprefix 0.0
# 580 getrules 0.0
# 581 getscanner 0.0
# 582 getscheme 0.0
# 583 getshortusername 0.0
# 584 getsnapshotdiff 0.0
# 585 getsnapshotdiffreport 0.0
# 586 getstandardtimelinegroupid 0.0
# 587 getstarttime 0.0
# 588 getstatus 0.0
# 589 getstring 0.0
# 590 gettable 0.0
# 591 gettablename 0.0
# 592 gettdmwithmemstore 0.0
# 593 gettdmwithstore 0.0
# 594 gettestdir 0.0
# 595 gettestrootpath 0.0
# 596 gettext 0.0
# 597 gettrashroot 0.0
# 598 gettype 0.0
# 599 getusername 0.0
# 600 getvalue 0.0
# 601 getvalues 0.0
# 602 getwebsocketcontainer 0.0
# 603 getworker 0.0
# 604 getxattrs 0.0
# 605 give 0.0
# 606 glarch 0.0
# 607 group 0.0
# 608 guest 0.0
# 609 h3#heading 0.0
# 610 hadoop 0.0
# 611 hadoopconf 0.0
# 612 handler 0.0
# 613 has 0.0
# 614 hasitem 0.0
# 615 hasmessage 0.0
# 616 hasrulesbeenset 0.0
# 617 have 0.0
# 618 hbaseconf 0.0
# 619 hbasetimelineschemautils 0.0
# 620 hbi 0.0
# 621 hdfs 0.0
# 622 hdfs/10 0.0
# 623 hello 0.0
# 624 here 0.0
# 625 hi 0.0
# 626 high 0.0
# 627 hold 0.0
# 628 holdbyme 0.0
# 629 home 0.0
# 630 http 0.0
# 631 http_ok 0.0
# 632 httpurlconnection 0.0
# 633 htu 0.0
# 634 i 0.0
# 635 id 0.0
# 636 id1 0.0
# 637 id3 0.0
# 638 id4 0.0
# 639 id5 0.0
# 640 id6 0.0
# 641 id7 0.0
# 642 id9 0.0
# 643 id_1 0.0
# 644 id_2 0.0
# 645 id_3 0.0
# 646 id_4 0.0
# 647 if 0.0
# 648 in 0.0
# 649 includes 0.0
# 650 incoming 0.0
# 651 indexof 0.0
# 652 info 0.0
# 653 infocolumns 0.0
# 654 infofilters=info2%20eq%203 0.0
# 655 infomap 0.0
# 656 infomap2 0.0
# 657 infomapkey1 0.0
# 658 infomapkey2 0.0
# 659 infomapvalue1 0.0
# 660 inherited 0.0
# 661 insensitive 0.0
# 662 instance 0.0
# 663 instanceid 0.0
# 664 instrumentation 0.0
# 665 integer 0.0
# 666 invocation 0.0
# 667 invokemethod 0.0
# 668 io-error 0.0
# 669 irrelevant 0.0
# 670 irrelevantdirpath 0.0
# 671 irrelevantfilepath 0.0
# 672 is 0.0
# 673 is_related_to_entity_id_here 0.0
# 674 iscanceled 0.0
# 675 isdisplayentityperuserfilterenabled 0.0
# 676 isempty 0.0
# 677 isequalto 0.0
# 678 isfinished 0.0
# 679 isfromkeytab 0.0
# 680 isinstanceof 0.0
# 681 isnotnull 0.0
# 682 isnotsameas 0.0
# 683 isopen 0.0
# 684 isrelatedto 0.0
# 685 isrelatedto2 0.0
# 686 isrelatedto= 0.0
# 687 isrelatedtoentity 0.0
# 688 isrelatedtoentry 0.0
# 689 isrelatedtoset 0.0
# 690 isrelatedtovalue 0.0
# 691 isrelatedtovalues 0.0
# 692 isrowkeycorrect 0.0
# 693 issameas 0.0
# 694 issecurityenabled 0.0
# 695 issnapshotenabled 0.0
# 696 issuccess 0.0
# 697 istrue 0.0
# 698 iswaiting 0.0
# 699 it 0.0
# 700 iterator 0.0
# 701 its 0.0
# 702 java 0.0
# 703 jettyutils 0.0
# 704 joe 0.0
# 705 joe/admin@foo 0.0
# 706 joe/root@foo 0.0
# 707 johndoe/zoo@foo 0.0
# 708 join 0.0
# 709 json 0.0
# 710 jsonfactory 0.0
# 711 jsonutil 0.0
# 712 kerberos 0.0
# 713 kerberosname 0.0
# 714 kerberosrule 0.0
# 715 kerberostestutils 0.0
# 716 kerberosutil 0.0
# 717 key 0.0
# 718 keytab 0.0
# 719 keytab_zk 0.0
# 720 lang 0.0
# 721 latch 0.0
# 722 lease 0.0
# 723 left 0.0
# 724 limit 0.0
# 725 limit=#$561av 0.0
# 726 limit=2 0.0
# 727 limit=3 0.0
# 728 line 0.0
# 729 list 0.0
# 730 liststatus 0.0
# 731 load 0.0
# 732 log 0.0
# 733 logfilename 0.0
# 734 logged 0.0
# 735 login 0.0
# 736 loginugi 0.0
# 737 logs 0.0
# 738 looks 0.0
# 739 m1 0.0
# 740 maintestappdirpath 0.0
# 741 maintestappid 0.0
# 742 make 0.0
# 743 manager 0.0
# 744 map 0.0
# 745 map<string 0.0
# 746 map_slot_millis 0.0
# 747 mask 0.0
# 748 match 0.0
# 749 matches 0.0
# 750 matchesgroupid 0.0
# 751 matchmetrics 0.0
# 752 mediatype 0.0
# 753 message 0.0
# 754 message-echo-hi 0.0
# 755 messageendpoint 0.0
# 756 messageformat 0.0
# 757 metric 0.0
# 758 metric2 0.0
# 759 metricfilters=metric3%20ge%200 0.0
# 760 metricfilters=metric7%20ge%200&isrelatedto=type1 0.0
# 761 metricmap 0.0
# 762 metrics 0.0
# 763 metrics2 0.0
# 764 metricsresult 0.0
# 765 metricvalues 0.0
# 766 metricvalues2 0.0
# 767 minidfs 0.0
# 768 mkdirs 0.0
# 769 mkpath 0.0
# 770 modaclspec 0.0
# 771 modify 0.0
# 772 modifyaclentries 0.0
# 773 modular-scale 0.0
# 774 most 0.0
# 775 movetodone 0.0
# 776 multi-thread 0.0
# 777 multiple 0.0
# 778 multiplequeryruns 0.0
# 779 name 0.0
# 780 name1 0.0
# 781 name2 0.0
# 782 name= 0.0
# 783 name={0}&op=instrumentation 0.0
# 784 name={0}&op=open&offset=1&length=2 0.0
# 785 name={1}&op=allowsnapshot 0.0
# 786 name={1}&op=disallowsnapshot 0.0
# 787 named 0.0
# 788 names 0.0
# 789 ncopies 0.0
# 790 new 0.0
# 791 newentity 0.0
# 792 newinstance 0.0
# 793 newly 0.0
# 794 next 0.0
# 795 nnconf 0.0
# 796 nobody 0.0
# 797 non-admin 0.0
# 798 none 0.0
# 799 nonnumericcolumnname 0.0
# 800 nonnumericcolumnname2 0.0
# 801 nonnumericcolumnname3 0.0
# 802 nonnumericcolumnname4 0.0
# 803 nonnumericrowkey 0.0
# 804 nonnumericrowkey2 0.0
# 805 nonnumericrowkey3 0.0
# 806 nonnumericvalue 0.0
# 807 nonnumericvalue2 0.0
# 808 nonnumericvalue3 0.0
# 809 nonnumericvalue4 0.0
# 810 normal 0.0
# 811 not 0.0
# 812 notunmaskeddir 0.0
# 813 notunmaskedfile 0.0
# 814 now 0.0
# 815 npe 0.0
# 816 null 0.0
# 817 number 0.0
# 818 numentityreadbefore 0.0
# 819 numtraces 0.0
# 820 objmapper 0.0
# 821 of 0.0
# 822 ofminutes 0.0
# 823 old 0.0
# 824 oldsnapshotname=snap-to-rename 0.0
# 825 omalley 0.0
# 826 omalley@ 0.0
# 827 on 0.0
# 828 one 0.0
# 829 one-line 0.0
# 830 onetime 0.0
# 831 onetimetask 0.0
# 832 onetimetaskinstance 0.0
# 833 onfailure 0.0
# 834 only 0.0
# 835 onresponse 0.0
# 836 oom 0.0
# 837 oom@yahoo 0.0
# 838 open 0.0
# 839 openconnection 0.0
# 840 orderedindex 0.0
# 841 orderedpropertyindexprovider 0.0
# 842 os 0.0
# 843 other 0.0
# 844 out 0.0
# 845 owner 0.0
# 846 p 0.0
# 847 params 0.0
# 848 parse 0.0
# 849 parseforstore 0.0
# 850 parsesummarylogs 0.0
# 851 part 0.0
# 852 path 0.0
# 853 path\ 0.0
# 854 pathafter 0.0
# 855 pathbefore 0.0
# 856 pathstr 0.0
# 857 pathstring 0.0
# 858 pathsuffix\ 0.0
# 859 pattern 0.0
# 860 per 0.0
# 861 perm 0.0
# 862 permission 0.0
# 863 permissions 0.0
# 864 pluginstoretestutils 0.0
# 865 plus 0.0
# 866 points 0.0
# 867 present 0.0
# 868 previouswebdriver 0.0
# 869 proc 0.0
# 870 proceduretestingutility 0.0
# 871 process 0.0
# 872 processor 0.0
# 873 procexecutor 0.0
# 874 procid 0.0
# 875 programaticerrorendpoint 0.0
# 876 properly 0.0
# 877 protocol=foo 0.0
# 878 ps 0.0
# 879 purge 0.0
# 880 put 0.0
# 881 putcmd 0.0
# 882 query 0.0
# 883 quickmessage 0.0
# 884 quit 0.0
# 885 r-- 0.0
# 886 r-x 0.0
# 887 rawcells 0.0
# 888 re-verify 0.0
# 889 read 0.0
# 890 readline 0.0
# 891 readresult 0.0
# 892 readresults 0.0
# 893 readresultswithtimestamps 0.0
# 894 realm 0.0
# 895 recent 0.0
# 896 reclaimed 0.0
# 897 reflected 0.0
# 898 reflectiontestutils 0.0
# 899 registrysecurity 0.0
# 900 registryutils 0.0
# 901 relates_to_entity_id_here 0.0
# 902 relates_to_entity_id_here_second 0.0
# 903 relatesto 0.0
# 904 relatesto2 0.0
# 905 relatesto= 0.0
# 906 relatestoentry 0.0
# 907 relatestoset 0.0
# 908 relatestovalues 0.0
# 909 releasefilesystem 0.0
# 910 remaclspec 0.0
# 911 remacluser1 0.0
# 912 remember 0.0
# 913 remove 0.0
# 914 removeacl 0.0
# 915 removeaclentries 0.0
# 916 removedefaultacl 0.0
# 917 removexattr 0.0
# 918 renamed 0.0
# 919 renamesnapshot 0.0
# 920 reply 0.0
# 921 request 0.0
# 922 reschedule 0.0
# 923 rescheduledexecutiontime 0.0
# 924 reset 0.0
# 925 resp 0.0
# 926 response 0.0
# 927 rest 0.0
# 928 restart 0.0
# 929 result 0.0
# 930 resultdomain 0.0
# 931 retain 0.0
# 932 retrievedentity 0.0
# 933 retrofit 0.0
# 934 return 0.0
# 935 returned 0.0
# 936 returns 0.0
# 937 rmacluser1 0.0
# 938 root 0.0
# 939 rounded-#{$side} 0.0
# 940 row1 0.0
# 941 rowcount 0.0
# 942 rowkey 0.0
# 943 rowkey2 0.0
# 944 rowkey2bytes 0.0
# 945 rowkey3 0.0
# 946 rowkey3bytes 0.0
# 947 rowkeybytes 0.0
# 948 rules 0.0
# 949 run 0.0
# 950 runconcurrently 0.0
# 951 runid 0.0
# 952 runtimeexception 0.0
# 953 rw- 0.0
# 954 rwx 0.0
# 955 s 0.0
# 956 same 0.0
# 957 sasl 0.0
# 958 scan 0.0
# 959 scanforlogs 0.0
# 960 scanned 0.0
# 961 scanner 0.0
# 962 schedule 0.0
# 963 scheduler 0.0
# 964 scheduler_should_execute_rescheduled_task_when_exactly_due 0.0
# 965 schedulerfor 0.0
# 966 second 0.0
# 967 seconds 0.0
# 968 security 0.0
# 969 see 0.0
# 970 select 0.0
# 971 send 0.0
# 972 sendrequestgetsnapshotdiff 0.0
# 973 sendtext 0.0
# 974 separator 0.0
# 975 server 0.0
# 976 serverendpointconfig 0.0
# 977 serverport 0.0
# 978 serverwebapp 0.0
# 979 service 0.0
# 980 services 0.0
# 981 session 0.0
# 982 set 0.0
# 983 set<string>> 0.0
# 984 setaccessible 0.0
# 985 setacl 0.0
# 986 setbatch 0.0
# 987 setboolean 0.0
# 988 setcreatedtime 0.0
# 989 setid 0.0
# 990 setisrelatedtoentities 0.0
# 991 setmaxversions 0.0
# 992 setname 0.0
# 993 setpermission 0.0
# 994 setproperty 0.0
# 995 setrelatestoentities 0.0
# 996 setrequestmethod 0.0
# 997 setscope 0.0
# 998 setsocketpolicy 0.0
# 999 setstartrow 0.0
# 1000 setthreshold 0.0
# 1001 setting 0.0
# 1002 settype 0.0
# 1003 setvalues 0.0
# 1004 setxattr 0.0
# 1005 setxattrparam 0.0
# 1006 shorter 0.0
# 1007 should 0.0
# 1008 shouldbeadifferentwebclient 0.0
# 1009 shouldbethreadsafe 0.0
# 1010 shouldbethreadsafewheninitializingprocessor 0.0
# 1011 shutdown 0.0
# 1012 single 0.0
# 1013 singlequeryrun 0.0
# 1014 size 0.0
# 1015 sleep 0.0
# 1016 snap-01 0.0
# 1017 snap-02 0.0
# 1018 snap-renamed 0.0
# 1019 snap-to-delete 0.0
# 1020 snap-to-rename 0.0
# 1021 snap-with-name 0.0
# 1022 snap1 0.0
# 1023 snap2 0.0
# 1024 snapshot 0.0
# 1025 snapshot/s 0.0
# 1026 snapshot/snap-with-name 0.0
# 1027 snapshotname=snap-to-delete 0.0
# 1028 snapshotname=snap-to-rename 0.0
# 1029 snapshotname=snap-with-name 0.0
# 1030 snapshots 0.0
# 1031 snapshottestpreconditions 0.0
# 1032 so 0.0
# 1033 socketpolicy 0.0
# 1034 some 0.0
# 1035 some_flow_name 0.0
# 1036 splitencoded 0.0
# 1037 sql2 0.0
# 1038 start 0.0
# 1039 starting 0.0
# 1040 startminidfs 0.0
# 1041 startrow 0.0
# 1042 status 0.0
# 1043 statusjson 0.0
# 1044 still 0.0
# 1045 stop 0.0
# 1046 storage 0.0
# 1047 store 0.0
# 1048 stream 0.0
# 1049 string 0.0
# 1050 stringkeyconverter 0.0
# 1051 stringutils 0.0
# 1052 sub 0.0
# 1053 subappuser 0.0
# 1054 subappuser1 0.0
# 1055 submitprocedure 0.0
# 1056 sufficiently 0.0
# 1057 summarylogentityread 0.0
# 1058 sure 0.0
# 1059 system 0.0
# 1060 t 0.0
# 1061 table 0.0
# 1062 tagname 0.0
# 1063 take 0.0
# 1064 task 0.0
# 1065 tdm 0.0
# 1066 te 0.0
# 1067 test 0.0
# 1068 test1 0.0
# 1069 test_app1_group1 0.0
# 1070 test_attempt_dir_name 0.0
# 1071 test_broken_file_name 0.0
# 1072 test_domain_file_name 0.0
# 1073 test_entity_file_name 0.0
# 1074 testabout 0.0
# 1075 testactivedirpath 0.0
# 1076 testallowsnapshot 0.0
# 1077 testannotatedclientendpoint 0.0
# 1078 testclassintrospector 0.0
# 1079 testcleanlogs 0.0
# 1080 testclosereason 0.0
# 1081 testcreatefilewithunmaskedpermissions 0.0
# 1082 testcreatesnapshot 0.0
# 1083 testcreatesnapshotnosnapshotname 0.0
# 1084 testdefaultrealmvalid 0.0
# 1085 testdelegationtokenoperations 0.0
# 1086 testdelegationtokenoperationsssl 0.0
# 1087 testdeletesnapshot 0.0
# 1088 testdiracls 0.0
# 1089 testdirhelper 0.0
# 1090 testdisallowsnapshot 0.0
# 1091 testdisallowsnapshotexception 0.0
# 1092 testdomain 0.0
# 1093 testdonedirpath 0.0
# 1094 testerrorhandling 0.0
# 1095 testfileacls 0.0
# 1096 testgetappattempt 0.0
# 1097 testgetappattempts 0.0
# 1098 testgetcontainer 0.0
# 1099 testgetcontainers 0.0
# 1100 testgetentities 0.0
# 1101 testgetentitiesbasedoncreatedtime 0.0
# 1102 testgetentitiesbyconfigfilters 0.0
# 1103 testgetentitiesbyeventfilters 0.0
# 1104 testgetentitiesbyinfofilters 0.0
# 1105 testgetentitiesbymetricfilters 0.0
# 1106 testgetentitiesbyrelations 0.0
# 1107 testgetentitiesnomatch 0.0
# 1108 testgetentitieswithlimit 0.0
# 1109 testgetentityallfields 0.0
# 1110 testgetentitycustomfields 0.0
# 1111 testgetentitydefaultview 0.0
# 1112 testgetentitynotpresent 0.0
# 1113 testgetentitypluginread 0.0
# 1114 testgetentitywithuserandflowinfo 0.0
# 1115 testgetsnapshotdiff 0.0
# 1116 testgetsnapshotdiffillegalparam 0.0
# 1117 testgettrashroot 0.0
# 1118 testgroupid 0.0
# 1119 testhadoopfilesystem 0.0
# 1120 testhdfshelp 0.0
# 1121 testhdfshelper 0.0
# 1122 testhttpfsserver 0.0
# 1123 testinvalidvalueshandling 0.0
# 1124 testjettyhelper 0.0
# 1125 testkerberosrulesvalid 0.0
# 1126 testlogbackstatusprinterprintstreamisrestoredtosystemout 0.0
# 1127 testloginfo 0.0
# 1128 testmatchesgroupid 0.0
# 1129 testmkdirwithunmaskedpermissions 0.0
# 1130 testmovetodone 0.0
# 1131 testopenoffsetlength 0.0
# 1132 testparsebrokenentity 0.0
# 1133 testparsedomain 0.0
# 1134 testparseentity 0.0
# 1135 testparsesummarylogs 0.0
# 1136 testperms 0.0
# 1137 testquerywithoutcluster 0.0
# 1138 testrenamesnapshot 0.0
# 1139 testrm 0.0
# 1140 testrules 0.0
# 1141 testserverwebapp0 0.0
# 1142 testsummaryread 0.0
# 1143 testtasks 0.0
# 1144 testtimelinereadermanageraclswhendisabled 0.0
# 1145 testtimelinereadermanageraclswhenenabled 0.0
# 1146 testugilogin 0.0
# 1147 testusernameextractionenvvaroverrride 0.0
# 1148 testwithnoacls 0.0
# 1149 testwithxattrs 0.0
# 1150 testwriteentitytohbase 0.0
# 1151 testwritescanbatchlimit 0.0
# 1152 testxattrs 0.0
# 1153 than 0.0
# 1154 that 0.0
# 1155 the 0.0
# 1156 theacl 0.0
# 1157 their 0.0
# 1158 then 0.0
# 1159 there 0.0
# 1160 third 0.0
# 1161 this 0.0
# 1162 thread 0.0
# 1163 tid1_1 0.0
# 1164 tid1_2 0.0
# 1165 tid2_1%60 0.0
# 1166 tid2_1%60&relatesto=flow 0.0
# 1167 time 0.0
# 1168 timeline 0.0
# 1169 timeline/apps/app1/entities/app 0.0
# 1170 timeline/apps/app1/entities/app/id_1 0.0
# 1171 timeline/clusters/cluster1/apps/app1/ 0.0
# 1172 timeline/clusters/cluster1/apps/app1/appattempts 0.0
# 1173 timeline/clusters/cluster1/apps/app1/appattempts/app-attempt-1 0.0
# 1174 timeline/clusters/cluster1/apps/app1/containers/container_2_2 0.0
# 1175 timeline/clusters/cluster1/apps/app1/entities/ 0.0
# 1176 timeline/clusters/cluster1/apps/app1/entities/app 0.0
# 1177 timeline/clusters/cluster1/apps/app1/entities/app/id_1 0.0
# 1178 timeline/clusters/cluster1/apps/app1/entities/app/id_10 0.0
# 1179 timeline/clusters/cluster1/apps/app1/entities/yarn_container 0.0
# 1180 timelineentitytype 0.0
# 1181 timelinemetric 0.0
# 1182 timelinereaderutils 0.0
# 1183 timelinereaderwebservices 0.0
# 1184 timeout 0.0
# 1185 to 0.0
# 1186 tobytes 0.0
# 1187 tojsonstring 0.0
# 1188 top 0.0
# 1189 tostring 0.0
# 1190 total 0.0
# 1191 totalentities 0.0
# 1192 touch 0.0
# 1193 touched 0.0
# 1194 trackevery 0.0
# 1195 trashjson 0.0
# 1196 trashpath 0.0
# 1197 true 0.0
# 1198 try 0.0
# 1199 ts 0.0
# 1200 two 0.0
# 1201 type 0.0
# 1202 type1 0.0
# 1203 type2 0.0
# 1204 type_1 0.0
# 1205 type_3 0.0
# 1206 u 0.0
# 1207 ugi 0.0
# 1208 ugiinfo 0.0
# 1209 uid 0.0
# 1210 under 0.0
# 1211 underlying 0.0
# 1212 unmaskeddir 0.0
# 1213 unmaskedfile 0.0
# 1214 unmatch 0.0
# 1215 unset 0.0
# 1216 unstructured] 0.0
# 1217 untouched 0.0
# 1218 up 0.0
# 1219 uri 0.0
# 1220 url 0.0
# 1221 user 0.0
# 1222 user1 0.0
# 1223 user1ugi 0.0
# 1224 user2 0.0
# 1225 user2ugi 0.0
# 1226 userapproot 0.0
# 1227 userbase 0.0
# 1228 usergroupinformation 0.0
# 1229 userid=user1&flowname=flow1&flowrunid=1 0.0
# 1230 userkey 0.0
# 1231 using 0.0
# 1232 util 0.0
# 1233 v 0.0
# 1234 validateauthuserwithentityuser 0.0
# 1235 validates 0.0
# 1236 value 0.0
# 1237 value1 0.0
# 1238 value2 0.0
# 1239 value2bytes 0.0
# 1240 value3 0.0
# 1241 value3bytes 0.0
# 1242 value4 0.0
# 1243 value4bytes 0.0
# 1244 valuebytes 0.0
# 1245 values 0.0
# 1246 verification 0.0
# 1247 verify 0.0
# 1248 verifyhttpresponse 0.0
# 1249 verifynotexists 0.0
# 1250 verifysubapplicationtableentities 0.0
# 1251 verifytestentities 0.0
# 1252 view 0.0
# 1253 waitfor 0.0
# 1254 we 0.0
# 1255 when 0.0
# 1256 whoami 0.0
# 1257 will 0.0
# 1258 with 0.0
# 1259 work 0.0
# 1260 works 0.0
# 1261 world 0.0
# 1262 writebytes 0.0
# 1263 writeentitiesleaveopen 0.0
# 1264 wrotestutils 0.0
# 1265 ws 0.0
# 1266 xattr 0.0
# 1267 xattrs 0.0
# 1268 yarn_application_attempt/app-attempt-1 0.0
# 1269 yarnconfiguration 0.0
# 1270 zkdelete 0.0
# 1271 zookeeper 0.0
# 1272 zookeeper_realm 0.0
# 1273 zookeeperconfigoptions 0.0
# 1274 { 0.0
# 1275 {border-#{$side}-radius 0.0
# 1276 {} 0.0
# 1277 } 0.0
